# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers

# %% [markdown]
# # Reading the CSV dataset & Pre-processing

# %%
dataset_path= r'../input/league-of-legends-diamond-ranked-games-10-min/high_diamond_ranked_10min.csv'
data= pd.read_csv(dataset_path)
print(f"The shape of the dataset is:> {data.shape} ie. rows:> {data.shape[0]} and columns:> {data.shape[1]}")
data.head(5)
# Out:
# The shape of the dataset is:> (9879, 40) ie. rows:> 9879 and columns:> 40
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   0         16567          6.8               17047
# 1                   1         17620          6.8               17438
# 2                   0         17285          6.8               17254
# 3                   0         16478          7.0               17961
# 4                   0         17404          7.0               18313
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    197                           55         -643
# 1                    240                           52         2908
# 2                    203                           28         1172
# 3                    235                           47         1321
# 4                    225                           67         1004
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0                  8         19.7         1656.7
# 1               1173         24.0         1762.0
# 2               1033         20.3         1728.5
# 3                  7         23.5         1647.8
# 4               -230         22.5         1740.4
#
# [5 rows x 40 columns]

# %%
#Since gameId is of no use for training the model so we can drop the gameId from the data
data.drop('gameId', axis=1, inplace=True) #axis=1 for horizontal axis

# %%
print(f"The new shape of the data after a column is deleted:> {data.shape}")
data.head(5)
# Out:
# The new shape of the data after a column is deleted:> (9879, 39)
#    blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 0         0               28                   2               1          9
# 1         0               12                   1               0          5
# 2         0               15                   0               0          7
# 3         0               43                   1               0          4
# 4         0               75                   4               0          6
#
#    blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  ...  \
# 0           6           11                  0            0            0  ...
# 1           5            5                  0            0            0  ...
# 2          11            4                  1            1            0  ...
# 3           5            5                  1            0            1  ...
# 4           6            6                  0            0            0  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   0         16567          6.8               17047
# 1                   1         17620          6.8               17438
# 2                   0         17285          6.8               17254
# 3                   0         16478          7.0               17961
# 4                   0         17404          7.0               18313
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    197                           55         -643
# 1                    240                           52         2908
# 2                    203                           28         1172
# 3                    235                           47         1321
# 4                    225                           67         1004
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0                  8         19.7         1656.7
# 1               1173         24.0         1762.0
# 2               1033         20.3         1728.5
# 3                  7         23.5         1647.8
# 4               -230         22.5         1740.4
#
# [5 rows x 39 columns]

# %%
#removing the column blueWins from the data as this is what is need to be predicted
y= data['blueWins']
X= data.drop('blueWins',axis=1, inplace=False)
print(f"The new shape of data is:> {X.shape}")
# Out:
# The new shape of data is:> (9879, 38)

# %% [markdown]
# # Correlation matrix
# Link:> https://www.statology.org/how-to-read-a-correlation-matrix/

# %%
sns.heatmap(X.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Splitting the Dataset
#
# A **ceil function** returns the smallest value that is greater or equal to the specified number while the **floor function** returns the largest number that is less than or equal to the number.

# %%
#checking for class imbalance
imbalances= y.sum()/y.shape
print(f"Since there is almost no class imbalance as the % is {imbalances[0]} ~ 50%, so we can use accuracy as a metric")
# Out:
# Since there is almost no class imbalance as the % is 0.4990383642069035 ~ 50%, so we can use accuracy as a metric

# %%
## train_test_split = 0.7

num_training_examples= int(X.shape[0] * train_test_split)
num_testing_examples= int(X.shape[0] - num_training_examples)

print(f"Training samples:> {num_training_examples} \nTesting samples:> {num_testing_examples}")

#extracting the rows based on the splits defined above
X_train= X.iloc[:num_training_examples,:]
Y_train= y.iloc[:num_training_examples]

X_test= X.iloc[num_training_examples:,:]
Y_test= y.iloc[num_training_examples:]

print(f"X_train:> {X_train.shape} Y_train:> {Y_train.shape} \nX_test:> {X_test.shape} Y_test:> {Y_test.shape} ")
# Out:
# Training samples:> 6915
# Testing samples:> 2964
# X_train:> (6915, 38) Y_train:> (6915,)
# X_test:> (2964, 38) Y_test:> (2964,)

# %% [markdown]
# # Defining and training the model
# callbacks: https://blog.paperspace.com/tensorflow-callbacks/

# %%
inputs = tf.keras.Input(shape=(X.shape[1],))
x = tf.keras.layers.Dense(19, activation=tf.nn.relu)(inputs)
x = tf.keras.layers.Dense(19, activation=tf.nn.relu)(x)
x = tf.keras.layers.Dense(19, activation=tf.nn.relu)(x)
x = tf.keras.layers.Dense(19, activation=tf.nn.relu)(x)
outputs = tf.keras.layers.Dense(2, activation=tf.nn.softmax)(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 38)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 19)                741
# _________________________________________________________________
# dense_13 (Dense)             (None, 19)                380
# _________________________________________________________________
# dense_14 (Dense)             (None, 19)                380
# _________________________________________________________________
# dense_15 (Dense)             (None, 19)                380
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 40
# =================================================================
# Total params: 1,921
# Trainable params: 1,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam'
)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
BATCH_SIZE = 32
EPOCHS = 500
rop= tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                     factor=0.1, 
                                     patience=10, 
                                     verbose=0, 
                                     mode='auto',    
                                     min_delta=0.0001, 
                                     cooldown=0, 
                                     min_lr=0)
es=tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                min_delta=0, 
                                patience=10, 
                                verbose=0, 
                                mode='auto', 
                                baseline=None, 
                                restore_best_weights=True)
callbacks_list= [rop,es]

history= model.fit(
    x=X_train,
    y=Y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    verbose=1,
    validation_split=0.2,
    shuffle=True,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/500
# 173/173 [==============================] - 1s 4ms/step - loss: 32.7053 - accuracy: 0.6473 - val_loss: 2.9470 - val_accuracy: 0.7129
# Epoch 2/500
# 173/173 [==============================] - 0s 2ms/step - loss: 3.3271 - accuracy: 0.6435 - val_loss: 2.4244 - val_accuracy: 0.5770
# Epoch 3/500
# 173/173 [==============================] - 0s 2ms/step - loss: 2.2011 - accuracy: 0.6446 - val_loss: 2.5788 - val_accuracy: 0.5416
# Epoch 4/500
# 173/173 [==============================] - 0s 2ms/step - loss: 2.4512 - accuracy: 0.6347 - val_loss: 3.2212 - val_accuracy: 0.5589
# Epoch 5/500
# 173/173 [==============================] - 0s 2ms/step - loss: 2.0141 - accuracy: 0.6437 - val_loss: 3.9303 - val_accuracy: 0.6175
# Epoch 6/500
# 173/173 [==============================] - 0s 2ms/step - loss: 1.9981 - accuracy: 0.6462 - val_loss: 1.8651 - val_accuracy: 0.6992
# Epoch 7/500
# 173/173 [==============================] - 0s 2ms/step - loss: 1.5802 - accuracy: 0.6473 - val_loss: 1.5606 - val_accuracy: 0.5271
# Epoch 8/500
# 173/173 [==============================] - 0s 2ms/step - loss: 2.2178 - accuracy: 0.6365 - val_loss: 1.3609 - val_accuracy: 0.7158
# Epoch 9/500
# 173/173 [==============================] - 0s 2ms/step - loss: 2.0353 - accuracy: 0.6499 - val_loss: 0.8234 - val_accuracy: 0.7086
# Epoch 10/500
# 173/173 [==============================] - 0s 3ms/step - loss: 1.2235 - accuracy: 0.6560 - val_loss: 1.5924 - val_accuracy: 0.5691
# Epoch 11/500
# 173/173 [==============================] - 0s 2ms/step - loss: 1.4698 - accuracy: 0.6428 - val_loss: 3.2305 - val_accuracy: 0.5748
# Epoch 12/500
# 173/173 [==============================] - 0s 3ms/step - loss: 1.1234 - accuracy: 0.6558 - val_loss: 0.6651 - val_accuracy: 0.6985
# Epoch 13/500
# 173/173 [==============================] - 1s 3ms/step - loss: 0.9504 - accuracy: 0.6538 - val_loss: 0.6484 - val_accuracy: 0.7137
# Epoch 14/500
# 173/173 [==============================] - 1s 3ms/step - loss: 1.0566 - accuracy: 0.6515 - val_loss: 0.6286 - val_accuracy: 0.7137
# Epoch 15/500
# 173/173 [==============================] - 0s 2ms/step - loss: 1.3100 - accuracy: 0.6540 - val_loss: 1.4660 - val_accuracy: 0.5683
# Epoch 16/500
# 173/173 [==============================] - 0s 2ms/step - loss: 1.0313 - accuracy: 0.6618 - val_loss: 0.7042 - val_accuracy: 0.6703
# Epoch 17/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.7802 - accuracy: 0.6687 - val_loss: 1.1310 - val_accuracy: 0.6255
# Epoch 18/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.9571 - accuracy: 0.6681 - val_loss: 0.6637 - val_accuracy: 0.6782
# Epoch 19/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.6375 - accuracy: 0.6866 - val_loss: 0.8157 - val_accuracy: 0.5965
# Epoch 20/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.7945 - accuracy: 0.6641 - val_loss: 0.5481 - val_accuracy: 0.7187
# Epoch 21/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.6235 - accuracy: 0.6790 - val_loss: 0.7129 - val_accuracy: 0.6775
# Epoch 22/500
# 173/173 [==============================] - 0s 3ms/step - loss: 0.6608 - accuracy: 0.6804 - val_loss: 0.8134 - val_accuracy: 0.6616
# Epoch 23/500
# 173/173 [==============================] - 0s 3ms/step - loss: 0.7792 - accuracy: 0.6728 - val_loss: 0.5568 - val_accuracy: 0.7151
# Epoch 24/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 0.6918 - val_loss: 0.5818 - val_accuracy: 0.7014
# Epoch 25/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.6057 - accuracy: 0.6950 - val_loss: 0.5708 - val_accuracy: 0.7158
# Epoch 26/500
# 173/173 [==============================] - 0s 3ms/step - loss: 0.5858 - accuracy: 0.7043 - val_loss: 0.5667 - val_accuracy: 0.7072
# Epoch 27/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.6125 - accuracy: 0.6884 - val_loss: 0.7108 - val_accuracy: 0.6529
# Epoch 28/500
# 173/173 [==============================] - 0s 3ms/step - loss: 0.6051 - accuracy: 0.6913 - val_loss: 0.5794 - val_accuracy: 0.7043
# Epoch 29/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.5740 - accuracy: 0.7044 - val_loss: 0.5504 - val_accuracy: 0.7057
# Epoch 30/500
# 173/173 [==============================] - 0s 2ms/step - loss: 0.5759 - accuracy: 0.6996 - val_loss: 0.5876 - val_accuracy: 0.6905

# %%
print(history.history.keys())
import matplotlib.pyplot as plt
# summarize training for accuracy
plt.plot(history.history['accuracy'])   # training is the variable from the fit method
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize traning for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
# Out:
# 93/93 [==============================] - 0s 1ms/step - loss: 0.5312 - accuracy: 0.7372
